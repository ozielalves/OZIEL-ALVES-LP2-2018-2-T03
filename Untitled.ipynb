# %%
import math as mt

# Question data:
total_cadeiras = 29
QE = 12684

# New
QP = 0
elec_votes = dict()
chairs_dist = dict()


# Reading csv
with open("eleicao.csv", encoding="utf-8") as f:
    f.readline()
    for line in f:
        pline = list(enumerate(line.split(";")))
        print(pline)
# Out:
# [(0, '10000'), (1, 'ANTONIO JUNIOR'), (2, 'PRB - PRB / PSDC'), (3, '434\n')]
# [(0, '10010'), (1, 'CIDINHA'), (2, 'PRB - PRB / PSDC'), (3, '36\n')]
# [(0, '10100'), (1, 'GABRIEL NEGREIROS'), (2, 'PRB - PRB / PSDC'), (3, '280\n')]
# [(0, '10111'), (1, 'JÚNIOR FRANÇA'), (2, 'PRB - PRB / PSDC'), (3, '568\n')]
# [(0, '10123'), (1, 'PROFª MADALENA PEIXOTO'), (2, 'PRB - PRB / PSDC'), (3, '382\n')]
# [(0, '10131'), (1, 'LUCIA ARDUINI'), (2, 'PRB - PRB / PSDC'), (3, '20\n')]
# [(0, '10144'), (1, 'HERÓ BEZERRA'), (2, 'PRB - PRB / PSDC'), (3, '422\n')]
# [(0, '10177'), (1, 'MYRNA KARENINA'), (2, 'PRB - PRB / PSDC'), (3, '209\n')]
# [(0, '10200'), (1, 'RIBAMAR'), (2, 'PRB - PRB / PSDC'), (3, '91\n')]
# [(0, '10222'), (1, 'DAVI'), (2, 'PRB - PRB / PSDC'), (3, '409\n')]
# [(0, '10333'), (1, 'BISPO FRANCISCO DE ASSIS'), (2, 'PRB - PRB / PSDC'), (3, '5160\n')]
# [(0, '10444'), (1, 'PASTOR TARQUINO JOSÉ'), (2, 'PRB - PRB / PSDC'), (3, '340\n')]
# [(0, '10555'), (1, 'KELLY MAIA'), (2, 'PRB - PRB / PSDC'), (3, '175\n')]
# [(0, '10777'), (1, 'IRMÃO JOÃO DA BENÇÃO'), (2, 'PRB - PRB / PSDC'), (3, '509\n')]
# [(0, '10789'), (1, 'JOÃO DA COSTA'), (2, 'PRB - PRB / PSDC'), (3, '217\n')]
# [(0, '10888'), (1, 'CRIS ROCHA'), (2, 'PRB - PRB / PSDC'), (3, '63\n')]
# [(0, '10999'), (1, 'VENINA'), (2, 'PRB - PRB / PSDC'), (3, '48\n')]
# [(0, '11111'), (1, 'VICTOR'), (2, 'PP - PEN / PP'), (3, '480\n')]
# [(0, '11112'), (1, 'JADELSON SALES'), (2, 'PP - PEN / PP'), (3, '169\n')]
# [(0, '11123'), (1, 'WESLEY BISMARK'), (2, 'PP - PEN / PP'), (3, '170\n')]
# [(0, '12000'), (1, 'JUNIOR GRAFITH'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '1635\n')]
# [(0, '12002'), (1, 'PAULINHA COSTUREIRA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '159\n')]
# [(0, '12007'), (1, 'DUCIRENE OLIVEIRA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '72\n')]
# [(0, '12012'), (1, 'EIDER ALVES'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '189\n')]
# [(0, '12100'), (1, 'RODRIGO GOMES'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '78\n')]
# [(0, '12110'), (1, 'FERNANDO SARAIVA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '312\n')]
# [(0, '12111'), (1, 'RANIERE BARBOSA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '10510\n')]
# [(0, '12114'), (1, 'NECY TEIXEIRA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '0\n')]
# [(0, '12122'), (1, 'VALERIA CAVALCANTI'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '714\n')]
# [(0, '12123'), (1, 'SÁVIO'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '1435\n')]
# [(0, '12151'), (1, 'PARDAL'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '135\n')]
# [(0, '12180'), (1, 'RHANNA DIOGENES'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '180\n')]
# [(0, '12222'), (1, 'KLEBER FERNANDES'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '5061\n')]
# [(0, '12300'), (1, 'NIVALDO PAPA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '90\n')]
# [(0, '12333'), (1, 'PÚBLIO JOSÉ'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '740\n')]
# [(0, '12345'), (1, 'AFRANIO AMORIM'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '364\n')]
# [(0, '12389'), (1, 'JONAS MADRUGA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '42\n')]
# [(0, '12444'), (1, 'CHAGAS CATARINO'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '4810\n')]
# [(0, '12555'), (1, 'LADE DAY'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '659\n')]
# [(0, '12580'), (1, 'PATRICIA COSTA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '8\n')]
# [(0, '12612'), (1, 'ARY GOMES'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '3488\n')]
# [(0, '12777'), (1, 'JULIA ARRUDA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '5765\n')]
# [(0, '12888'), (1, 'WALTER AGRA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '208\n')]
# [(0, '12999'), (1, 'ELMA SOUZA'), (2, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '559\n')]
# [(0, '13007'), (1, 'ERIVAN FERNANDES'), (2, 'PT'), (3, '146\n')]
# [(0, '13013'), (1, 'RODRIGO BICO'), (2, 'PT'), (3, '1782\n')]
# [(0, '13100'), (1, 'MILKLEI LEITE'), (2, 'PT'), (3, '1704\n')]
# [(0, '13111'), (1, 'ADAIRTON MEDEIROS'), (2, 'PT'), (3, '112\n')]
# [(0, '13113'), (1, 'FATIMA CARDOSO'), (2, 'PT'), (3, '2037\n')]
# [(0, '13116'), (1, 'YÁ LUCIENE'), (2, 'PT'), (3, '168\n')]
# [(0, '13123'), (1, 'NATALIA BONAVIDES'), (2, 'PT'), (3, '6202\n')]
# [(0, '13131'), (1, 'CHIQUINHO'), (2, 'PT'), (3, '330\n')]
# [(0, '13133'), (1, 'DANIEL LEMOS'), (2, 'PT'), (3, '305\n')]
# [(0, '13221'), (1, 'VALTÉCIA SÁ'), (2, 'PT'), (3, '57\n')]
# [(0, '13222'), (1, 'FERNANDO LUCENA'), (2, 'PT'), (3, '2495\n')]
# [(0, '13223'), (1, 'PROF WALKER FRANCIS'), (2, 'PT'), (3, '650\n')]
# [(0, '13300'), (1, 'MARAVILHOSO'), (2, 'PT'), (3, '36\n')]
# [(0, '13313'), (1, 'PROFESSORA RUTH'), (2, 'PT'), (3, '196\n')]
# [(0, '13333'), (1, 'PROF NILDO'), (2, 'PT'), (3, '187\n')]
# [(0, '13611'), (1, 'HUGO MANSO'), (2, 'PT'), (3, '1899\n')]
# [(0, '13613'), (1, 'DIVANEIDE'), (2, 'PT'), (3, '2236\n')]
# [(0, '13777'), (1, 'IRAN CÉSAR'), (2, 'PT'), (3, '42\n')]
# [(0, '13789'), (1, 'MARQUINHO'), (2, 'PT'), (3, '1005\n')]
# [(0, '13999'), (1, 'PROF ADRIANO BARROS'), (2, 'PT'), (3, '1611\n')]
# [(0, '14000'), (1, 'CÍCERO MARTINS'), (2, 'PTB - PSD / PTB / PSL'), (3, '3237\n')]
# [(0, '14111'), (1, 'SIQUEIRA'), (2, 'PTB - PSD / PTB / PSL'), (3, '477\n')]
# [(0, '14123'), (1, 'SANDEMBERG OLIVEIRA'), (2, 'PTB - PSD / PTB / PSL'), (3, '204\n')]
# [(0, '14222'), (1, 'MÁRIO EMERENCIANO'), (2, 'PTB - PSD / PTB / PSL'), (3, '1109\n')]
# [(0, '14444'), (1, 'ARQUELAUS SÁTIRO'), (2, 'PTB - PSD / PTB / PSL'), (3, '2159\n')]
# [(0, '14555'), (1, 'DOVER GOIS'), (2, 'PTB - PSD / PTB / PSL'), (3, '213\n')]
# [(0, '14567'), (1, 'GRACIELA LANDWOIGT'), (2, 'PTB - PSD / PTB / PSL'), (3, '87\n')]
# [(0, '15000'), (1, 'TERCEIRO DANTAS'), (2, 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '555\n')]
# [(0, '15222'), (1, 'UBALDO FERNANDES'), (2, 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '7574\n')]
# [(0, '15555'), (1, 'DRA KÁTIA NUNES'), (2, 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '1128\n')]
# [(0, '15678'), (1, 'FELIPE ALVES'), (2, 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '4511\n')]
# [(0, '16123'), (1, 'AMANDA GURGEL'), (2, 'PSTU'), (3, '8002\n')]
# [(0, '16161'), (1, 'ALEXANDRE GUEDES'), (2, 'PSTU'), (3, '103\n')]
# [(0, '16234'), (1, 'SILVINO BAÚ'), (2, 'PSTU'), (3, '292\n')]
# [(0, '16345'), (1, 'ANTONIA MARINHO'), (2, 'PSTU'), (3, '28\n')]
# [(0, '16456'), (1, 'MARCOS AURELIO'), (2, 'PSTU'), (3, '415\n')]
# [(0, '16543'), (1, 'CELIA DANTAS'), (2, 'PSTU'), (3, '288\n')]
# [(0, '16666'), (1, 'AILSON MATIAS'), (2, 'PSTU'), (3, '5\n')]
# [(0, '16777'), (1, 'EDINEIDE AMORIM'), (2, 'PSTU'), (3, '18\n')]
# [(0, '16780'), (1, 'EMANUEL ALVER'), (2, 'PSTU'), (3, '70\n')]
# [(0, '16789'), (1, 'DARIO BARBOSA'), (2, 'PSTU'), (3, '848\n')]
# [(0, '16888'), (1, 'CHERLITON SARAIVA'), (2, 'PSTU'), (3, '5\n')]
# [(0, '17000'), (1, 'LENINHA'), (2, 'PSL - PSD / PTB / PSL'), (3, '45\n')]
# [(0, '17333'), (1, 'WILSON COLLIER JR, COLLIER'), (2, 'PSL - PSD / PTB / PSL'), (3, '153\n')]
# [(0, '17555'), (1, 'PROFESSORA ELEIKA'), (2, 'PSL - PSD / PTB / PSL'), (3, '3758\n')]
# [(0, '17700'), (1, 'ARTHUR DUTRA'), (2, 'PSL - PSD / PTB / PSL'), (3, '2099\n')]
# [(0, '17777'), (1, 'DR MONTE NETO'), (2, 'PSL - PSD / PTB / PSL'), (3, '578\n')]
# [(0, '17888'), (1, 'PROFESSOR HUDSON PALHANO'), (2, 'PSL - PSD / PTB / PSL'), (3, '701\n')]
# [(0, '18010'), (1, 'ARNALDO DA OFICINA'), (2, 'REDE'), (3, '24\n')]
# [(0, '18018'), (1, 'MÃE DA REVOLTA DO BUSÃO'), (2, 'REDE'), (3, '42\n')]
# [(0, '18153'), (1, 'JOÃO NAPOLEÃO'), (2, 'REDE'), (3, '129\n')]
# [(0, '18333'), (1, 'IDER FREIRE'), (2, 'REDE'), (3, '214\n')]
# [(0, '18888'), (1, 'JEANE FLAVIA'), (2, 'REDE'), (3, '88\n')]
# [(0, '19000'), (1, 'ENGRACIA ALVES'), (2, 'PTN'), (3, '457\n')]
# [(0, '19001'), (1, 'KATIA SILENE'), (2, 'PTN'), (3, '2\n')]
# [(0, '19002'), (1, 'DILMA'), (2, 'PTN'), (3, '2\n')]
# [(0, '19003'), (1, 'ZITA'), (2, 'PTN'), (3, '2\n')]
# [(0, '19004'), (1, 'MILENA KARLA'), (2, 'PTN'), (3, '0\n')]
# [(0, '19090'), (1, 'BUDA'), (2, 'PTN'), (3, '117\n')]
# [(0, '19099'), (1, 'RENER'), (2, 'PTN'), (3, '1006\n')]
# [(0, '19100'), (1, 'CLOTILDE GODEIRO'), (2, 'PTN'), (3, '879\n')]
# [(0, '19110'), (1, 'ADALÉCIO'), (2, 'PTN'), (3, '499\n')]
# [(0, '19111'), (1, 'ZEZINHO'), (2, 'PTN'), (3, '731\n')]
# [(0, '19122'), (1, 'JOAOZINHO'), (2, 'PTN'), (3, '79\n')]
# [(0, '19123'), (1, 'IZAQUE OLIVEIRA'), (2, 'PTN'), (3, '912\n')]
# [(0, '19128'), (1, 'ROSILANDY FEITOSA'), (2, 'PTN'), (3, '84\n')]
# [(0, '19133'), (1, 'ERIKO JÁCOME'), (2, 'PTN'), (3, '2577\n')]
# [(0, '19150'), (1, 'ADELMA FELIX'), (2, 'PTN'), (3, '17\n')]
# [(0, '19190'), (1, 'RAQUEL TAVEIRA'), (2, 'PTN'), (3, '334\n')]
# [(0, '19191'), (1, 'PROFª ANA MOURA'), (2, 'PTN'), (3, '63\n')]
# [(0, '19199'), (1, 'ALUISIO LEILÃO'), (2, 'PTN'), (3, '583\n')]
# [(0, '19200'), (1, 'EDOMIRO BANDEIRA'), (2, 'PTN'), (3, '374\n')]
# [(0, '19222'), (1, 'VICTOR NOÉ'), (2, 'PTN'), (3, '1355\n')]
# [(0, '19223'), (1, 'GILMAR COSTA'), (2, 'PTN'), (3, '285\n')]
# [(0, '19234'), (1, 'GILSON ALVES'), (2, 'PTN'), (3, '16\n')]
# [(0, '19300'), (1, 'RODOLFO DE FARIAS'), (2, 'PTN'), (3, '106\n')]
# [(0, '19333'), (1, 'MARCIO GOMES'), (2, 'PTN'), (3, '1006\n')]
# [(0, '19400'), (1, 'SALETE CAMPELO'), (2, 'PTN'), (3, '898\n')]
# [(0, '19444'), (1, 'ITANILDO REIS'), (2, 'PTN'), (3, '1015\n')]
# [(0, '19456'), (1, 'PEDRO HENRIQUE'), (2, 'PTN'), (3, '1054\n')]
# [(0, '19555'), (1, 'JOSY'), (2, 'PTN'), (3, '4\n')]
# [(0, '19580'), (1, 'JOESLY CORRETOR'), (2, 'PTN'), (3, '29\n')]
# [(0, '19600'), (1, 'SERGIO MOURA'), (2, 'PTN'), (3, '75\n')]
# [(0, '19678'), (1, 'RERISON GUERREIRO'), (2, 'PTN'), (3, '0\n')]
# [(0, '19700'), (1, 'ARNÓBIO LEÃO'), (2, 'PTN'), (3, '77\n')]
# [(0, '19727'), (1, 'ORIVAL JUNIOR'), (2, 'PTN'), (3, '0\n')]
# [(0, '19777'), (1, 'PAULINHO'), (2, 'PTN'), (3, '495\n')]
# [(0, '19800'), (1, 'ADSON GURGEL'), (2, 'PTN'), (3, '274\n')]
# [(0, '19888'), (1, 'JAILSON'), (2, 'PTN'), (3, '251\n')]
# [(0, '19999'), (1, 'CARLOS SANTOS'), (2, 'PTN'), (3, '0\n')]
# [(0, '20001'), (1, 'ISMAR VAMBORA'), (2, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '150\n')]
# [(0, '20016'), (1, 'ESAM ELALI'), (2, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '437\n')]
# [(0, '20111'), (1, 'ANUBIO MELO'), (2, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '572\n')]
# [(0, '20123'), (1, 'THIAGO NASCIMENTO'), (2, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '338\n')]
# [(0, '20321'), (1, 'MISSIONARIA CRISTIANE'), (2, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '478\n')]
# [(0, '22123'), (1, 'CESAR DE ADÃO ERIDAN'), (2, 'PR - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '2768\n')]
# [(0, '22222'), (1, 'MARCIA SOUZA'), (2, 'PR - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '94\n')]
# [(0, '22607'), (1, 'LUIZ ALMIR'), (2, 'PR - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '7339\n')]
# [(0, '22777'), (1, 'ELIAS PELA SAÚDE JUSTA'), (2, 'PR - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '271\n')]
# [(0, '23000'), (1, 'FLAVIA JOTA'), (2, 'PPS - PSB / PPS'), (3, '70\n')]
# [(0, '23001'), (1, 'ZECA DO IGAPOÍ'), (2, 'PPS - PSB / PPS'), (3, '137\n')]
# [(0, '23008'), (1, 'GORETI MARIA CHAVES PINHEIRO'), (2, 'PPS - PSB / PPS'), (3, '19\n')]
# [(0, '23023'), (1, 'MARRY'), (2, 'PPS - PSB / PPS'), (3, '1\n')]
# [(0, '23100'), (1, 'ITALO BORGES'), (2, 'PPS - PSB / PPS'), (3, '218\n')]
# [(0, '23123'), (1, 'EDUARDO MACHADO'), (2, 'PPS - PSB / PPS'), (3, '3002\n')]
# [(0, '23222'), (1, 'BETO'), (2, 'PPS - PSB / PPS'), (3, '242\n')]
# [(0, '23232'), (1, 'YURI PETROVICH'), (2, 'PPS - PSB / PPS'), (3, '13\n')]
# [(0, '23321'), (1, 'JOÃO DA JÓIA'), (2, 'PPS - PSB / PPS'), (3, '3\n')]
# [(0, '23333'), (1, 'JOÃO RAFAEL'), (2, 'PPS - PSB / PPS'), (3, '1597\n')]
# [(0, '23363'), (1, 'JOÃO GRANDE'), (2, 'PPS - PSB / PPS'), (3, '2\n')]
# [(0, '23444'), (1, 'LUIZINHO'), (2, 'PPS - PSB / PPS'), (3, '1017\n')]
# [(0, '23456'), (1, 'CLEONICE'), (2, 'PPS - PSB / PPS'), (3, '81\n')]
# [(0, '23543'), (1, 'MONICA GUERREIRO'), (2, 'PPS - PSB / PPS'), (3, '15\n')]
# [(0, '23555'), (1, 'ANCHIETA'), (2, 'PPS - PSB / PPS'), (3, '403\n')]
# [(0, '23666'), (1, 'EZIEL'), (2, 'PPS - PSB / PPS'), (3, '105\n')]
# [(0, '23777'), (1, 'GARI ALDAIR'), (2, 'PPS - PSB / PPS'), (3, '178\n')]
# [(0, '25123'), (1, 'DAGÔ'), (2, 'DEM - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '3428\n')]
# [(0, '25125'), (1, 'FERNANDO CALDAS'), (2, 'DEM - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '59\n')]
# [(0, '27000'), (1, 'LUCINETE'), (2, 'PSDC - PRB / PSDC'), (3, '7\n')]
# [(0, '27001'), (1, 'TIO ALEGRIA'), (2, 'PSDC - PRB / PSDC'), (3, '42\n')]
# [(0, '27007'), (1, 'IVONE BRAZIL'), (2, 'PSDC - PRB / PSDC'), (3, '413\n')]
# [(0, '27030'), (1, 'KAROL POSADZKI'), (2, 'PSDC - PRB / PSDC'), (3, '2\n')]
# [(0, '27033'), (1, 'PESCOCINHO'), (2, 'PSDC - PRB / PSDC'), (3, '210\n')]
# [(0, '27111'), (1, 'RICARDO MENDONÇA'), (2, 'PSDC - PRB / PSDC'), (3, '452\n')]
# [(0, '27123'), (1, 'ZÉ UNIÃO'), (2, 'PSDC - PRB / PSDC'), (3, '199\n')]
# [(0, '27127'), (1, 'SILAS SOUZA'), (2, 'PSDC - PRB / PSDC'), (3, '57\n')]
# [(0, '27177'), (1, 'EIDER VIANA'), (2, 'PSDC - PRB / PSDC'), (3, '156\n')]
# [(0, '27192'), (1, 'SÉRGIO CÔCO'), (2, 'PSDC - PRB / PSDC'), (3, '318\n')]
# [(0, '27200'), (1, 'TIAGO OLIVEIRA'), (2, 'PSDC - PRB / PSDC'), (3, '86\n')]
# [(0, '27222'), (1, 'PROF GUARÁ'), (2, 'PSDC - PRB / PSDC'), (3, '267\n')]
# [(0, '27282'), (1, 'ACASSIA'), (2, 'PSDC - PRB / PSDC'), (3, '56\n')]
# [(0, '27333'), (1, 'RAMINHO'), (2, 'PSDC - PRB / PSDC'), (3, '656\n')]
# [(0, '27444'), (1, 'EMANOEL DO CAÇÃO'), (2, 'PSDC - PRB / PSDC'), (3, '1433\n')]
# [(0, '27527'), (1, 'SANDRO LIRA'), (2, 'PSDC - PRB / PSDC'), (3, '21\n')]
# [(0, '27555'), (1, 'KLEBSON RIBEIRO'), (2, 'PSDC - PRB / PSDC'), (3, '605\n')]
# [(0, '27666'), (1, 'DINHO'), (2, 'PSDC - PRB / PSDC'), (3, '112\n')]
# [(0, '27747'), (1, 'RAMBO DE NATAL'), (2, 'PSDC - PRB / PSDC'), (3, '214\n')]
# [(0, '27772'), (1, 'IRAPUAN'), (2, 'PSDC - PRB / PSDC'), (3, '0\n')]
# [(0, '27777'), (1, 'DR JOANILSON'), (2, 'PSDC - PRB / PSDC'), (3, '1082\n')]
# [(0, '27789'), (1, 'JOÃO GAGO'), (2, 'PSDC - PRB / PSDC'), (3, '67\n')]
# [(0, '27888'), (1, 'ANA PAULA'), (2, 'PSDC - PRB / PSDC'), (3, '5465\n')]
# [(0, '28334'), (1, 'MARCELO FRAGOSO'), (2, 'PRTB - PRP / PTC / PRTB / PMN'), (3, '169\n')]
# [(0, '28456'), (1, 'LAURO LIMA O CANCÃO'), (2, 'PRTB - PRP / PTC / PRTB / PMN'), (3, '274\n')]
# [(0, '28888'), (1, 'MAJ RODRIGUES'), (2, 'PRTB - PRP / PTC / PRTB / PMN'), (3, '714\n')]
# [(0, '31000'), (1, 'DR ISAAC MÁRIO'), (2, 'PHS'), (3, '1314\n')]
# [(0, '31009'), (1, 'EDNA CÂMARA'), (2, 'PHS'), (3, '0\n')]
# [(0, '31022'), (1, 'LEOMAR DANTAS'), (2, 'PHS'), (3, '495\n')]
# [(0, '31033'), (1, 'PAULO ENFERMEIRO'), (2, 'PHS'), (3, '1141\n')]
# [(0, '31073'), (1, 'SGTº SOUZA'), (2, 'PHS'), (3, '92\n')]
# [(0, '31110'), (1, 'EMANUELLA GOMES'), (2, 'PHS'), (3, '3\n')]
# [(0, '31111'), (1, 'LEANDRO PRUDENCIO'), (2, 'PHS'), (3, '1082\n')]
# [(0, '31113'), (1, 'ENEDINO BATISTINHA'), (2, 'PHS'), (3, '135\n')]
# [(0, '31118'), (1, 'DANIEL PONTES'), (2, 'PHS'), (3, '137\n')]
# [(0, '31122'), (1, 'CARLÃO'), (2, 'PHS'), (3, '647\n')]
# [(0, '31123'), (1, 'FATIMA LEAO'), (2, 'PHS'), (3, '490\n')]
# [(0, '31134'), (1, 'FRANCISCO CANUTO'), (2, 'PHS'), (3, '8\n')]
# [(0, '31135'), (1, 'ADAMIRES COSTA'), (2, 'PHS'), (3, '280\n')]
# [(0, '31147'), (1, 'IRON BURITI'), (2, 'PHS'), (3, '178\n')]
# [(0, '31163'), (1, 'ERIVAL COSTA'), (2, 'PHS'), (3, '39\n')]
# [(0, '31190'), (1, 'LEONCIO QUEIROZ'), (2, 'PHS'), (3, '664\n')]
# [(0, '31202'), (1, 'NILDO BORRACHEIRO'), (2, 'PHS'), (3, '96\n')]
# [(0, '31222'), (1, 'PEDRINHO NO CORAÇÃO'), (2, 'PHS'), (3, '611\n')]
# [(0, '31223'), (1, 'TATIANA BULHOES'), (2, 'PHS'), (3, '80\n')]
# [(0, '31234'), (1, 'NENEM SANTANA'), (2, 'PHS'), (3, '387\n')]
# [(0, '31236'), (1, 'IRMÃ GORETE'), (2, 'PHS'), (3, '10\n')]
# [(0, '31288'), (1, 'EDSON ZUZA'), (2, 'PHS'), (3, '656\n')]
# [(0, '31300'), (1, 'ITAMIR DE SOUSA'), (2, 'PHS'), (3, '29\n')]
# [(0, '31314'), (1, 'REY POP SHOW'), (2, 'PHS'), (3, '63\n')]
# [(0, '31323'), (1, 'LUIZ ROCHA'), (2, 'PHS'), (3, '281\n')]
# [(0, '31331'), (1, 'GERSON PAIS'), (2, 'PHS'), (3, '54\n')]
# [(0, '31333'), (1, 'PEDRO CORDEIRO'), (2, 'PHS'), (3, '386\n')]
# [(0, '31382'), (1, 'ROSIANA CORDEIRO'), (2, 'PHS'), (3, '1\n')]
# [(0, '31412'), (1, 'ALAIDE SOARES'), (2, 'PHS'), (3, '4\n')]
# [(0, '31444'), (1, 'HIDELBRANDO GONÇALVES'), (2, 'PHS'), (3, '405\n')]
# [(0, '31456'), (1, 'SUELDO MEDEIROS'), (2, 'PHS'), (3, '1829\n')]
# [(0, '31553'), (1, 'OLIVEIRA PEDRO'), (2, 'PHS'), (3, '215\n')]
# [(0, '31555'), (1, 'FRANKLIN DE ANDRADE'), (2, 'PHS'), (3, '84\n')]
# [(0, '31666'), (1, 'DONA JEANE'), (2, 'PHS'), (3, '74\n')]
# [(0, '31689'), (1, 'MARCIA SAMARA'), (2, 'PHS'), (3, '0\n')]
# [(0, '31735'), (1, 'MARIA BARBOSA'), (2, 'PHS'), (3, '0\n')]
# [(0, '31770'), (1, 'ONIVALDO JUNIOR'), (2, 'PHS'), (3, '307\n')]
# [(0, '31777'), (1, 'IRMÃO GILBERTO'), (2, 'PHS'), (3, '1308\n')]
# [(0, '31842'), (1, 'MARIA INES'), (2, 'PHS'), (3, '0\n')]
# [(0, '31888'), (1, 'ALEX TOMAZ'), (2, 'PHS'), (3, '505\n')]
# [(0, '31992'), (1, 'ANA COSTA'), (2, 'PHS'), (3, '3\n')]
# [(0, '31999'), (1, 'SANDRA SANTOS'), (2, 'PHS'), (3, '945\n')]
# [(0, '33000'), (1, 'SARGENTO SERGIO PASTEL'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '580\n')]
# [(0, '33024'), (1, 'ANECARINE'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '0\n')]
# [(0, '33111'), (1, 'MAJOR PARAGUAI'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '324\n')]
# [(0, '33123'), (1, 'JAUFRAN SIQUEIRA'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '0\n')]
# [(0, '33190'), (1, 'SARGENTO TEIXEIRA'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '71\n')]
# [(0, '33333'), (1, 'IGOR RAFAEL'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '1618\n')]
# [(0, '33456'), (1, 'GENILSON SOARES'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '59\n')]
# [(0, '33777'), (1, 'IRMÃO RENATO'), (2, 'PMN - PRP / PTC / PRTB / PMN'), (3, '337\n')]
# [(0, '35000'), (1, 'SARGENTO ROGERIO'), (2, 'PMB'), (3, '807\n')]
# [(0, '35001'), (1, 'ROMILDO JUNIOR'), (2, 'PMB'), (3, '429\n')]
# [(0, '35003'), (1, 'MARISE DEFENSORA DOS ANIMAIS'), (2, 'PMB'), (3, '93\n')]
# [(0, '35006'), (1, 'MARIA CARVALHO'), (2, 'PMB'), (3, '914\n')]
# [(0, '35007'), (1, 'DINARTE TORRES'), (2, 'PMB'), (3, '2754\n')]
# [(0, '35035'), (1, 'JAIR PEREIRA'), (2, 'PMB'), (3, '130\n')]
# [(0, '35055'), (1, 'SILVIO DANTAS'), (2, 'PMB'), (3, '1183\n')]
# [(0, '35077'), (1, 'ISABEL MIRANDA'), (2, 'PMB'), (3, '12\n')]
# [(0, '35100'), (1, 'JOÃO DAS RODAS'), (2, 'PMB'), (3, '104\n')]
# [(0, '35110'), (1, 'PREGADORA ANA SELMA'), (2, 'PMB'), (3, '402\n')]
# [(0, '35111'), (1, 'RENATO BEZERRA'), (2, 'PMB'), (3, '392\n')]
# [(0, '35122'), (1, 'NIVALDO BACURAU'), (2, 'PMB'), (3, '1624\n')]
# [(0, '35123'), (1, 'PRISCILA AZEVEDO'), (2, 'PMB'), (3, '419\n')]
# [(0, '35124'), (1, 'RICARDINHO DO PLANALTO'), (2, 'PMB'), (3, '1185\n')]
# [(0, '35125'), (1, 'WISLLEY LIMA (AMOR)'), (2, 'PMB'), (3, '682\n')]
# [(0, '35135'), (1, 'MAX PAIVA'), (2, 'PMB'), (3, '406\n')]
# [(0, '35144'), (1, 'CONSTANTINO'), (2, 'PMB'), (3, '321\n')]
# [(0, '35171'), (1, 'DR CARLOS ROBERTO'), (2, 'PMB'), (3, '81\n')]
# [(0, '35177'), (1, 'SOCORRO BATISTA'), (2, 'PMB'), (3, '93\n')]
# [(0, '35178'), (1, 'CARIDADE'), (2, 'PMB'), (3, '16\n')]
# [(0, '35190'), (1, 'DELEGADO SERGIO LEOCÁDIO'), (2, 'PMB'), (3, '1169\n')]
# [(0, '35191'), (1, 'DAGMAR AGENTE DE SAÚDE'), (2, 'PMB'), (3, '79\n')]
# [(0, '35192'), (1, 'DANIEL JUNIOR'), (2, 'PMB'), (3, '635\n')]
# [(0, '35222'), (1, 'MARLENE RAMALHO'), (2, 'PMB'), (3, '1242\n')]
# [(0, '35223'), (1, 'CHAGAS NUNES'), (2, 'PMB'), (3, '178\n')]
# [(0, '35233'), (1, 'WALKER COSTA'), (2, 'PMB'), (3, '578\n')]
# [(0, '35234'), (1, 'NICE'), (2, 'PMB'), (3, '163\n')]
# [(0, '35321'), (1, 'JOSY KARLA'), (2, 'PMB'), (3, '252\n')]
# [(0, '35333'), (1, 'ROSANA FARIAS'), (2, 'PMB'), (3, '282\n')]
# [(0, '35355'), (1, 'ELIANE SANTOS'), (2, 'PMB'), (3, '65\n')]
# [(0, '35400'), (1, 'CLEUDIVAN BEZERRA'), (2, 'PMB'), (3, '96\n')]
# [(0, '35444'), (1, 'EDUARDO GOMES'), (2, 'PMB'), (3, '794\n')]
# [(0, '35500'), (1, 'MAXWELL TRINDADE'), (2, 'PMB'), (3, '848\n')]
# [(0, '35555'), (1, 'ROBSON CARVALHO'), (2, 'PMB'), (3, '2565\n')]
# [(0, '35653'), (1, 'MANOEL EDUARDO'), (2, 'PMB'), (3, '1787\n')]
# [(0, '35666'), (1, 'VERA DA ACADEMIA'), (2, 'PMB'), (3, '120\n')]
# [(0, '35678'), (1, 'ALDO CLEMENTE'), (2, 'PMB'), (3, '2229\n')]
# [(0, '35700'), (1, 'ITAMAR MONTEIRO'), (2, 'PMB'), (3, '267\n')]
# [(0, '35777'), (1, 'DANIEL ARRUDA'), (2, 'PMB'), (3, '1929\n')]
# [(0, '35789'), (1, 'ANIZIO'), (2, 'PMB'), (3, '750\n')]
# [(0, '35888'), (1, 'DELZIMAR SOARES'), (2, 'PMB'), (3, '383\n')]
# [(0, '35890'), (1, 'MARCOS FREIRE'), (2, 'PMB'), (3, '171\n')]
# [(0, '36000'), (1, 'KARLA JEANE'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '18\n')]
# [(0, '36100'), (1, 'PASTOR ED LIMA'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '233\n')]
# [(0, '36104'), (1, 'JOAQUIM JÚNIOR'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '44\n')]
# [(0, '36111'), (1, 'FRAN ROCHA'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '43\n')]
# [(0, '36123'), (1, 'AJOSILEIDE ALVES'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '193\n')]
# [(0, '36133'), (1, 'ZILDETE LIRA'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '3\n')]
# [(0, '36136'), (1, 'PROFESSOR GARRIDO'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '0\n')]
# [(0, '36166'), (1, 'BELCHIOR REIS'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '35\n')]
# [(0, '36171'), (1, 'CARRAPICHO'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '120\n')]
# [(0, '36190'), (1, 'SUBTENENTE MAVIGNIER'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '175\n')]
# [(0, '36333'), (1, 'JAQUES ABENÇOADO'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '220\n')]
# [(0, '36456'), (1, 'WELLINGTON GOMES'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '116\n')]
# [(0, '36543'), (1, 'GILDETE PINHEIRO'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '59\n')]
# [(0, '36666'), (1, 'ALLYSON GOMES'), (2, 'PTC - PRP / PTC / PRTB / PMN'), (3, '97\n')]
# [(0, '40007'), (1, 'PROFESSOR RONIELE SANTOS'), (2, 'PSB - PSB / PPS'), (3, '233\n')]
# [(0, '40100'), (1, 'SEVERINA ALVES'), (2, 'PSB - PSB / PPS'), (3, '278\n')]
# [(0, '40123'), (1, 'ARAKEN FARIAS'), (2, 'PSB - PSB / PPS'), (3, '559\n')]
# [(0, '40125'), (1, 'GUIMARÃES'), (2, 'PSB - PSB / PPS'), (3, '0\n')]
# [(0, '40127'), (1, 'JOÃO MARIA'), (2, 'PSB - PSB / PPS'), (3, '55\n')]
# [(0, '40170'), (1, 'VILMA DA SAÚDE'), (2, 'PSB - PSB / PPS'), (3, '261\n')]
# [(0, '40200'), (1, 'DR FRANKLIN CAPISTRANO'), (2, 'PSB - PSB / PPS'), (3, '4003\n')]
# [(0, '40222'), (1, 'ZÉ ROBERTO FELIX'), (2, 'PSB - PSB / PPS'), (3, '146\n')]
# [(0, '40321'), (1, 'XÊNIA COSTA'), (2, 'PSB - PSB / PPS'), (3, '43\n')]
# [(0, '40333'), (1, 'JAILTON FELICIANO'), (2, 'PSB - PSB / PPS'), (3, '457\n')]
# [(0, '40442'), (1, 'NAYANE NUNES'), (2, 'PSB - PSB / PPS'), (3, '108\n')]
# [(0, '40456'), (1, 'BRUNO CARLOS'), (2, 'PSB - PSB / PPS'), (3, '315\n')]
# [(0, '40555'), (1, 'NILDO ANGELO'), (2, 'PSB - PSB / PPS'), (3, '909\n')]
# [(0, '40666'), (1, 'OZILENE GARCIA'), (2, 'PSB - PSB / PPS'), (3, '18\n')]
# [(0, '40777'), (1, 'MATHEUS PERES'), (2, 'PSB - PSB / PPS'), (3, '156\n')]
# [(0, '40789'), (1, 'PAULO NERIS DO SANGUE'), (2, 'PSB - PSB / PPS'), (3, '144\n')]
# [(0, '40888'), (1, 'JOÃO DO VALE'), (2, 'PSB - PSB / PPS'), (3, '364\n')]
# [(0, '43000'), (1, 'DR TADEU ALENCAR'), (2, 'PV'), (3, '491\n')]
# [(0, '43002'), (1, 'ANTONIO WALDEMAR'), (2, 'PV'), (3, '15\n')]
# [(0, '43003'), (1, 'MARGARETH ALVES'), (2, 'PV'), (3, '0\n')]
# [(0, '43013'), (1, 'THAYANE LOPES MIRANDA'), (2, 'PV'), (3, '0\n')]
# [(0, '43043'), (1, 'LÉO ALMEIDA'), (2, 'PV'), (3, '566\n')]
# [(0, '43069'), (1, 'SHEILA VULCÃO'), (2, 'PV'), (3, '47\n')]
# [(0, '43100'), (1, 'PROFESSOR JULIO BEZERRIL'), (2, 'PV'), (3, '43\n')]
# [(0, '43111'), (1, 'DR MARILTON'), (2, 'PV'), (3, '204\n')]
# [(0, '43123'), (1, 'ROBERTO LOPES'), (2, 'PV'), (3, '349\n')]
# [(0, '43133'), (1, 'HERMES'), (2, 'PV'), (3, '1425\n')]
# [(0, '43200'), (1, 'MATIAS DELEGADO'), (2, 'PV'), (3, '78\n')]
# [(0, '43213'), (1, 'CARLOS ALEXANDRE'), (2, 'PV'), (3, '212\n')]
# [(0, '43216'), (1, 'LUIZ INACIO'), (2, 'PV'), (3, '132\n')]
# [(0, '43222'), (1, 'PROFº IVONALDO'), (2, 'PV'), (3, '166\n')]
# [(0, '43223'), (1, 'LUCINÉIA FLORÊNCIO'), (2, 'PV'), (3, '77\n')]
# [(0, '43233'), (1, 'PROFESSOR AURICÉLIO LUCENA'), (2, 'PV'), (3, '140\n')]
# [(0, '43234'), (1, 'ROBSON SOARES'), (2, 'PV'), (3, '147\n')]
# [(0, '43321'), (1, 'CORDEIRO DO TIROL'), (2, 'PV'), (3, '128\n')]
# [(0, '43333'), (1, 'MARCELO GUEDES'), (2, 'PV'), (3, '209\n')]
# [(0, '43343'), (1, 'NELLY CARLOS'), (2, 'PV'), (3, '82\n')]
# [(0, '43345'), (1, 'ALEX MAUHEL'), (2, 'PV'), (3, '414\n')]
# [(0, '43433'), (1, 'LUZIA BARBOSA'), (2, 'PV'), (3, '140\n')]
# [(0, '43443'), (1, 'ELIANA TORRES'), (2, 'PV'), (3, '60\n')]
# [(0, '43456'), (1, 'MARINA MELO'), (2, 'PV'), (3, '161\n')]
# [(0, '43555'), (1, 'IRMAO DAILTON'), (2, 'PV'), (3, '132\n')]
# [(0, '43666'), (1, 'CAMARADA LETO'), (2, 'PV'), (3, '7\n')]
# [(0, '43670'), (1, 'JOÃO BARBOSA'), (2, 'PV'), (3, '244\n')]
# [(0, '43789'), (1, 'DANIEL GÊNESIS'), (2, 'PV'), (3, '51\n')]
# [(0, '43987'), (1, 'DHÉBORA MARTINS'), (2, 'PV'), (3, '1\n')]
# [(0, '43999'), (1, 'GILMAR DO DEPOSITO'), (2, 'PV'), (3, '1361\n')]
# [(0, '44000'), (1, 'ADRIANA TRINDADE'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '398\n')]
# [(0, '44002'), (1, 'SUZIANY FERNANDES'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '3\n')]
# [(0, '44007'), (1, 'FLAVIO GENTIL'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '224\n')]
# [(0, '44111'), (1, 'PAULO YURI'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '133\n')]
# [(0, '44123'), (1, 'PAULINHO VILELA'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '710\n')]
# [(0, '44234'), (1, 'REINALDO JUNIOR'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '155\n')]
# [(0, '44333'), (1, 'SUELY CIDRAO'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '99\n')]
# [(0, '44344'), (1, 'SUZANA FERNANDES'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '0\n')]
# [(0, '44355'), (1, 'SIMONE FERNANDES'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '6\n')]
# [(0, '44444'), (1, 'CAPITÃO NILO'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '1843\n')]
# [(0, '44555'), (1, 'HEINER BRANDAO'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '66\n')]
# [(0, '44777'), (1, 'NILDO'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '258\n')]
# [(0, '44888'), (1, 'RAFAELLA MAGNA'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '1\n')]
# [(0, '44999'), (1, 'JUNIOR CAPOEIRA'), (2, 'PRP - PRP / PTC / PRTB / PMN'), (3, '198\n')]
# [(0, '45000'), (1, 'GILENILDO'), (2, 'PSDB - PSDB / PT do B'), (3, '1601\n')]
# [(0, '45001'), (1, 'ADRIANA SHIEILA'), (2, 'PSDB - PSDB / PT do B'), (3, '13\n')]
# [(0, '45007'), (1, 'DELEGADO FABIO ROGERIO'), (2, 'PSDB - PSDB / PT do B'), (3, '614\n')]
# [(0, '45008'), (1, 'BEL COSTA'), (2, 'PSDB - PSDB / PT do B'), (3, '17\n')]
# [(0, '45011'), (1, 'NEUMA'), (2, 'PSDB - PSDB / PT do B'), (3, '1\n')]
# [(0, '45055'), (1, 'NEILDE'), (2, 'PSDB - PSDB / PT do B'), (3, '0\n')]
# [(0, '45066'), (1, 'LUZIA'), (2, 'PSDB - PSDB / PT do B'), (3, '1\n')]
# [(0, '45111'), (1, 'ALBERT EINSTEIN'), (2, 'PSDB - PSDB / PT do B'), (3, '224\n')]
# [(0, '45123'), (1, 'AROLDO ALVES'), (2, 'PSDB - PSDB / PT do B'), (3, '4532\n')]
# [(0, '45212'), (1, 'LUCIANA'), (2, 'PSDB - PSDB / PT do B'), (3, '23\n')]
# [(0, '45222'), (1, 'MAXWELL MELLO'), (2, 'PSDB - PSDB / PT do B'), (3, '19\n')]
# [(0, '45345'), (1, 'JOSINALDO'), (2, 'PSDB - PSDB / PT do B'), (3, '143\n')]
# [(0, '45444'), (1, 'RENNAN NUNES'), (2, 'PSDB - PSDB / PT do B'), (3, '438\n')]
# [(0, '45451'), (1, 'MARIA JOSE'), (2, 'PSDB - PSDB / PT do B'), (3, '74\n')]
# [(0, '45456'), (1, 'DR CARLOS CAMAL'), (2, 'PSDB - PSDB / PT do B'), (3, '155\n')]
# [(0, '45555'), (1, 'DICKSON NASSER JR'), (2, 'PSDB - PSDB / PT do B'), (3, '3662\n')]
# [(0, '45678'), (1, 'ROSEMBERG CORTEZ'), (2, 'PSDB - PSDB / PT do B'), (3, '430\n')]
# [(0, '45777'), (1, 'GILSON LOURENÇO'), (2, 'PSDB - PSDB / PT do B'), (3, '54\n')]
# [(0, '45888'), (1, 'JURACIR'), (2, 'PSDB - PSDB / PT do B'), (3, '324\n')]
# [(0, '45999'), (1, 'TADEU ARRUDA'), (2, 'PSDB - PSDB / PT do B'), (3, '226\n')]
# [(0, '50000'), (1, 'MARCOS TINOCO'), (2, 'PSOL'), (3, '165\n')]
# [(0, '50009'), (1, 'FABIANO COSTA'), (2, 'PSOL'), (3, '112\n')]
# [(0, '50011'), (1, 'DELCIO NEGAO'), (2, 'PSOL'), (3, '19\n')]
# [(0, '50015'), (1, 'ADEGILSON ESPERANÇA'), (2, 'PSOL'), (3, '517\n')]
# [(0, '50024'), (1, 'ARETHA MELO'), (2, 'PSOL'), (3, '246\n')]
# [(0, '50044'), (1, 'FRANCISCO CANINDE'), (2, 'PSOL'), (3, '157\n')]
# [(0, '50051'), (1, 'GEOMAR'), (2, 'PSOL'), (3, '246\n')]
# [(0, '50055'), (1, 'MALU'), (2, 'PSOL'), (3, '215\n')]
# [(0, '50100'), (1, 'CRIS LIMA'), (2, 'PSOL'), (3, '150\n')]
# [(0, '50111'), (1, 'MAZINHO COSTA'), (2, 'PSOL'), (3, '544\n')]
# [(0, '50113'), (1, 'JEFFERSON HASILLE'), (2, 'PSOL'), (3, '587\n')]
# [(0, '50114'), (1, 'JESSICA ALVES'), (2, 'PSOL'), (3, '2\n')]
# [(0, '50122'), (1, 'MIRANDINHA DO PLANALTO'), (2, 'PSOL'), (3, '306\n')]
# [(0, '50123'), (1, 'SANDRO PIMENTEL'), (2, 'PSOL'), (3, '3700\n')]
# [(0, '50124'), (1, 'CLENIO LUCAS'), (2, 'PSOL'), (3, '160\n')]
# [(0, '50144'), (1, 'PROF ALEXANDRE TAVARES'), (2, 'PSOL'), (3, '359\n')]
# [(0, '50150'), (1, 'PROFESSORA MILCA'), (2, 'PSOL'), (3, '245\n')]
# [(0, '50192'), (1, 'FRANCISCA FARIAS'), (2, 'PSOL'), (3, '166\n')]
# [(0, '50200'), (1, 'ROSANGELA DA RECICLAGEM'), (2, 'PSOL'), (3, '45\n')]
# [(0, '50220'), (1, 'KANELINHA'), (2, 'PSOL'), (3, '55\n')]
# [(0, '50222'), (1, 'MAURICIO GURGEL'), (2, 'PSOL'), (3, '3167\n')]
# [(0, '50223'), (1, 'ALDANIR CARVALHO'), (2, 'PSOL'), (3, '78\n')]
# [(0, '50230'), (1, 'JADIEL FREIRE DA SILVA'), (2, 'PSOL'), (3, '92\n')]
# [(0, '50234'), (1, 'AMADO BATISTA COVER'), (2, 'PSOL'), (3, '51\n')]
# [(0, '50322'), (1, 'RICHARDSON BARBOSA'), (2, 'PSOL'), (3, '100\n')]
# [(0, '50332'), (1, 'LIZIÊR MORAIS'), (2, 'PSOL'), (3, '58\n')]
# [(0, '50444'), (1, 'BRENO CAMACHO'), (2, 'PSOL'), (3, '1304\n')]
# [(0, '50450'), (1, 'TASSO SILVA DE OLIVEIRA'), (2, 'PSOL'), (3, '9\n')]
# [(0, '50456'), (1, 'MARCOS ANTONIO PSOL'), (2, 'PSOL'), (3, '1251\n')]
# [(0, '50505'), (1, 'SANDRO TOMAZ'), (2, 'PSOL'), (3, '67\n')]
# [(0, '50555'), (1, 'SONIA GODEIRO'), (2, 'PSOL'), (3, '464\n')]
# [(0, '50777'), (1, 'DANIELA'), (2, 'PSOL'), (3, '338\n')]
# [(0, '50789'), (1, 'JUCIÊ LIMA'), (2, 'PSOL'), (3, '15\n')]
# [(0, '50800'), (1, 'SOL'), (2, 'PSOL'), (3, '211\n')]
# [(0, '50888'), (1, 'TIAGO DA AUTO ESCOLA'), (2, 'PSOL'), (3, '1689\n')]
# [(0, '50999'), (1, 'EDUARDO MONTEIRO'), (2, 'PSOL'), (3, '143\n')]
# [(0, '51000'), (1, 'SERGIO PINHEIRO'), (2, 'PEN - PEN / PP'), (3, '1862\n')]
# [(0, '51001'), (1, 'INGRID HANNA'), (2, 'PEN - PEN / PP'), (3, '149\n')]
# [(0, '51004'), (1, 'DRª ROBERTA'), (2, 'PEN - PEN / PP'), (3, '122\n')]
# [(0, '51006'), (1, 'BEZERRA DO SINDICATO'), (2, 'PEN - PEN / PP'), (3, '44\n')]
# [(0, '51007'), (1, 'ANCHIETA FELIX'), (2, 'PEN - PEN / PP'), (3, '546\n')]
# [(0, '51013'), (1, 'VANY ALVES'), (2, 'PEN - PEN / PP'), (3, '8\n')]
# [(0, '51015'), (1, 'BEBETO'), (2, 'PEN - PEN / PP'), (3, '222\n')]
# [(0, '51020'), (1, 'VOVÓ MARLENE'), (2, 'PEN - PEN / PP'), (3, '96\n')]
# [(0, '51051'), (1, 'CIDINHO MEDEIROS'), (2, 'PEN - PEN / PP'), (3, '587\n')]
# [(0, '51091'), (1, 'CEIÇA DANTAS'), (2, 'PEN - PEN / PP'), (3, '0\n')]
# [(0, '51100'), (1, 'ZE HUMBERTO'), (2, 'PEN - PEN / PP'), (3, '1335\n')]
# [(0, '51111'), (1, 'NINA SOUZA'), (2, 'PEN - PEN / PP'), (3, '2289\n')]
# [(0, '51115'), (1, 'PROFESSORA RAISSA'), (2, 'PEN - PEN / PP'), (3, '5\n')]
# [(0, '51123'), (1, 'RODRIGO DANTAS'), (2, 'PEN - PEN / PP'), (3, '173\n')]
# [(0, '51165'), (1, 'VERA LUCIA'), (2, 'PEN - PEN / PP'), (3, '0\n')]
# [(0, '51190'), (1, 'JONAS MOTOBOY'), (2, 'PEN - PEN / PP'), (3, '335\n')]
# [(0, '51192'), (1, 'ELIEL DO GAS'), (2, 'PEN - PEN / PP'), (3, '217\n')]
# [(0, '51200'), (1, 'SENNA'), (2, 'PEN - PEN / PP'), (3, '219\n')]
# [(0, '51221'), (1, 'ERINEIDE TORRES'), (2, 'PEN - PEN / PP'), (3, '25\n')]
# [(0, '51222'), (1, 'CARLOS BELEZAL'), (2, 'PEN - PEN / PP'), (3, '204\n')]
# [(0, '51224'), (1, 'ZÉ AESCIO'), (2, 'PEN - PEN / PP'), (3, '652\n')]
# [(0, '51233'), (1, 'DAMIAO POTENCIA'), (2, 'PEN - PEN / PP'), (3, '145\n')]
# [(0, '51234'), (1, 'GLAUCE MOURA'), (2, 'PEN - PEN / PP'), (3, '69\n')]
# [(0, '51302'), (1, 'JOSE NEPOMUCENO'), (2, 'PEN - PEN / PP'), (3, '342\n')]
# [(0, '51321'), (1, 'EDMUNDO'), (2, 'PEN - PEN / PP'), (3, '88\n')]
# [(0, '51333'), (1, 'EDILSON DUVALLE'), (2, 'PEN - PEN / PP'), (3, '129\n')]
# [(0, '51345'), (1, 'XAVIER QUEIXINHO'), (2, 'PEN - PEN / PP'), (3, '240\n')]
# [(0, '51444'), (1, 'IVANILSON OLIVEIRA'), (2, 'PEN - PEN / PP'), (3, '263\n')]
# [(0, '51510'), (1, 'BLACK SHOW'), (2, 'PEN - PEN / PP'), (3, '560\n')]
# [(0, '51515'), (1, 'RUTEMBERG ROCHA'), (2, 'PEN - PEN / PP'), (3, '90\n')]
# [(0, '51551'), (1, 'JORGE DANTAS'), (2, 'PEN - PEN / PP'), (3, '0\n')]
# [(0, '51555'), (1, 'WANESSA MEDEIROS'), (2, 'PEN - PEN / PP'), (3, '351\n')]
# [(0, '51610'), (1, 'PRETO AQUINO'), (2, 'PEN - PEN / PP'), (3, '4206\n')]
# [(0, '51644'), (1, 'MARCOS DO POTENGI'), (2, 'PEN - PEN / PP'), (3, '146\n')]
# [(0, '51666'), (1, 'LUIZ ANTONIO'), (2, 'PEN - PEN / PP'), (3, '42\n')]
# [(0, '51707'), (1, 'NASTAGNAN BATISTA'), (2, 'PEN - PEN / PP'), (3, '899\n')]
# [(0, '51789'), (1, 'DR JOSUE'), (2, 'PEN - PEN / PP'), (3, '607\n')]
# [(0, '51800'), (1, 'JOAO MARIA CORRETO'), (2, 'PEN - PEN / PP'), (3, '439\n')]
# [(0, '51888'), (1, 'WENDY SILVA'), (2, 'PEN - PEN / PP'), (3, '58\n')]
# [(0, '51991'), (1, 'SUELEIDE PEREIRA DA SILVA'), (2, 'PEN - PEN / PP'), (3, '0\n')]
# [(0, '51999'), (1, 'WARTA DANTAS'), (2, 'PEN - PEN / PP'), (3, '31\n')]
# [(0, '55000'), (1, 'JOÃO BATISTA TORRES'), (2, 'PSD - PSD / PTB / PSL'), (3, '868\n')]
# [(0, '55111'), (1, 'LILICO BEZERRA'), (2, 'PSD - PSD / PTB / PSL'), (3, '3155\n')]
# [(0, '55122'), (1, 'CHICO AMBULANTE'), (2, 'PSD - PSD / PTB / PSL'), (3, '313\n')]
# [(0, '55123'), (1, 'DR ENILDO'), (2, 'PSD - PSD / PTB / PSL'), (3, '1713\n')]
# [(0, '55125'), (1, 'FERNANDO CUNHA'), (2, 'PSD - PSD / PTB / PSL'), (3, '77\n')]
# [(0, '55222'), (1, 'ASSIS OLIVEIRA'), (2, 'PSD - PSD / PTB / PSL'), (3, '1456\n')]
# [(0, '55234'), (1, 'HERON MANGABEIRA'), (2, 'PSD - PSD / PTB / PSL'), (3, '475\n')]
# [(0, '55333'), (1, 'DELEGADO LUCENA'), (2, 'PSD - PSD / PTB / PSL'), (3, '1289\n')]
# [(0, '55400'), (1, 'REGINA SABINO'), (2, 'PSD - PSD / PTB / PSL'), (3, '0\n')]
# [(0, '55444'), (1, 'LILI ABREU'), (2, 'PSD - PSD / PTB / PSL'), (3, '47\n')]
# [(0, '55456'), (1, 'ERINELSON MORAIS'), (2, 'PSD - PSD / PTB / PSL'), (3, '286\n')]
# [(0, '55550'), (1, 'MARIA CLEIDE'), (2, 'PSD - PSD / PTB / PSL'), (3, '0\n')]
# [(0, '55555'), (1, 'NEY LOPES JR'), (2, 'PSD - PSD / PTB / PSL'), (3, '3197\n')]
# [(0, '55666'), (1, 'CIDÃO'), (2, 'PSD - PSD / PTB / PSL'), (3, '73\n')]
# [(0, '55678'), (1, 'PROF MARIO NOVAES'), (2, 'PSD - PSD / PTB / PSL'), (3, '176\n')]
# [(0, '55777'), (1, 'FRANCISCO CUNHA'), (2, 'PSD - PSD / PTB / PSL'), (3, '182\n')]
# [(0, '55789'), (1, 'MARIA DE FATIMA VARELA'), (2, 'PSD - PSD / PTB / PSL'), (3, '1\n')]
# [(0, '55800'), (1, 'JARDENIRA FERNANDES'), (2, 'PSD - PSD / PTB / PSL'), (3, '0\n')]
# [(0, '55888'), (1, 'ROCHINHA'), (2, 'PSD - PSD / PTB / PSL'), (3, '2245\n')]
# [(0, '55999'), (1, 'JUREMA'), (2, 'PSD - PSD / PTB / PSL'), (3, '168\n')]
# [(0, '65000'), (1, 'DANIEL FERNANDES'), (2, 'PC do B'), (3, '354\n')]
# [(0, '65001'), (1, 'LUIZ CLÁUDIO'), (2, 'PC do B'), (3, '271\n')]
# [(0, '65002'), (1, 'SIMONE SILVA'), (2, 'PC do B'), (3, '0\n')]
# [(0, '65003'), (1, 'DIANA CABRAL'), (2, 'PC do B'), (3, '44\n')]
# [(0, '65005'), (1, 'JOSELITO TAXISTA'), (2, 'PC do B'), (3, '216\n')]
# [(0, '65010'), (1, 'PROFESSOR EURICO'), (2, 'PC do B'), (3, '695\n')]
# [(0, '65084'), (1, 'IRMÃ EDILMA'), (2, 'PC do B'), (3, '251\n')]
# [(0, '65100'), (1, 'GERALDO ALVES'), (2, 'PC do B'), (3, '123\n')]
# [(0, '65110'), (1, 'LUCIANO TERTULINO BARBOSA'), (2, 'PC do B'), (3, '208\n')]
# [(0, '65111'), (1, 'PAULA SANTOS'), (2, 'PC do B'), (3, '69\n')]
# [(0, '65114'), (1, 'ÍTALO ANDERSON'), (2, 'PC do B'), (3, '85\n')]
# [(0, '65123'), (1, 'GEORGE CÂMARA'), (2, 'PC do B'), (3, '2006\n')]
# [(0, '65126'), (1, 'JOSENILSON'), (2, 'PC do B'), (3, '39\n')]
# [(0, '65160'), (1, 'KINEN'), (2, 'PC do B'), (3, '79\n')]
# [(0, '65165'), (1, 'JOÃO MEU QUERIDO'), (2, 'PC do B'), (3, '74\n')]
# [(0, '65190'), (1, 'CABO JEOAS'), (2, 'PC do B'), (3, '1578\n')]
# [(0, '65222'), (1, 'CRISTINA SANTOS'), (2, 'PC do B'), (3, '124\n')]
# [(0, '65321'), (1, 'VALECIA'), (2, 'PC do B'), (3, '278\n')]
# [(0, '65333'), (1, 'XANDÃO'), (2, 'PC do B'), (3, '630\n')]
# [(0, '65444'), (1, 'PROFESSOR ZÉ CARLOS'), (2, 'PC do B'), (3, '110\n')]
# [(0, '65555'), (1, 'MARCIO MELO'), (2, 'PC do B'), (3, '61\n')]
# [(0, '65656'), (1, 'MOACIR SOARES'), (2, 'PC do B'), (3, '256\n')]
# [(0, '65666'), (1, 'MILENA'), (2, 'PC do B'), (3, '75\n')]
# [(0, '65678'), (1, 'OLGA AGUIAR'), (2, 'PC do B'), (3, '345\n')]
# [(0, '65777'), (1, 'MARCELINO'), (2, 'PC do B'), (3, '73\n')]
# [(0, '65789'), (1, 'ROGÉRIO OLIVEIRA'), (2, 'PC do B'), (3, '204\n')]
# [(0, '65800'), (1, 'CARLINHOS DEFICIENTE'), (2, 'PC do B'), (3, '119\n')]
# [(0, '65888'), (1, 'MARIA CUNHA'), (2, 'PC do B'), (3, '5\n')]
# [(0, '65999'), (1, 'RICARDO GUEDES'), (2, 'PC do B'), (3, '57\n')]
# [(0, '70000'), (1, 'SGT HUMBERTO'), (2, 'PT do B - PSDB / PT do B'), (3, '276\n')]
# [(0, '70100'), (1, 'GISLENO NENE'), (2, 'PT do B - PSDB / PT do B'), (3, '130\n')]
# [(0, '70111'), (1, 'WILMA DE FARIA'), (2, 'PT do B - PSDB / PT do B'), (3, '4421\n')]
# [(0, '70112'), (1, 'ALEXSANDRA ROCHA'), (2, 'PT do B - PSDB / PT do B'), (3, '80\n')]
# [(0, '70123'), (1, 'EDINHO GUERRA'), (2, 'PT do B - PSDB / PT do B'), (3, '1374\n')]
# [(0, '70170'), (1, 'EDIVANILSON BEBETO'), (2, 'PT do B - PSDB / PT do B'), (3, '30\n')]
# [(0, '70190'), (1, 'ARIBERTO'), (2, 'PT do B - PSDB / PT do B'), (3, '955\n')]
# [(0, '70200'), (1, 'JULIANA DUTRA'), (2, 'PT do B - PSDB / PT do B'), (3, '96\n')]
# [(0, '70222'), (1, 'RAFA MAIA'), (2, 'PT do B - PSDB / PT do B'), (3, '5\n')]
# [(0, '70330'), (1, 'JOSELITO'), (2, 'PT do B - PSDB / PT do B'), (3, '301\n')]
# [(0, '70400'), (1, 'ANA DO LEITE'), (2, 'PT do B - PSDB / PT do B'), (3, '109\n')]
# [(0, '70444'), (1, 'PASTOR SILVESTRE'), (2, 'PT do B - PSDB / PT do B'), (3, '269\n')]
# [(0, '70555'), (1, 'WILSON JUNIOR'), (2, 'PT do B - PSDB / PT do B'), (3, '44\n')]
# [(0, '70770'), (1, 'DILMA MARIA'), (2, 'PT do B - PSDB / PT do B'), (3, '44\n')]
# [(0, '70777'), (1, 'PROF, WALTER FAGUNDES'), (2, 'PT do B - PSDB / PT do B'), (3, '145\n')]
# [(0, '70810'), (1, 'GLOVANE GOMES'), (2, 'PT do B - PSDB / PT do B'), (3, '43\n')]
# [(0, '70888'), (1, 'MANU NUNES'), (2, 'PT do B - PSDB / PT do B'), (3, '127\n')]
# [(0, '77000'), (1, 'JAILTON FEITOSA'), (2, 'SD'), (3, '98\n')]
# [(0, '77001'), (1, 'JAIR DANTAS'), (2, 'SD'), (3, '774\n')]
# [(0, '77007'), (1, 'LUCIO GUGU'), (2, 'SD'), (3, '140\n')]
# [(0, '77010'), (1, 'HIRAM GARÇON'), (2, 'SD'), (3, '37\n')]
# [(0, '77011'), (1, 'IVAN O TERRIVEL'), (2, 'SD'), (3, '182\n')]
# [(0, '77016'), (1, 'MAURICIO FORMIGA'), (2, 'SD'), (3, '219\n')]
# [(0, '77077'), (1, 'AUGUSTO VARELLA'), (2, 'SD'), (3, '1251\n')]
# [(0, '77100'), (1, 'DANIELE SOUTO'), (2, 'SD'), (3, '128\n')]
# [(0, '77111'), (1, 'NÚBIA BARBOSA'), (2, 'SD'), (3, '773\n')]
# [(0, '77123'), (1, 'DIEGO OLIVEIRA'), (2, 'SD'), (3, '1010\n')]
# [(0, '77142'), (1, 'EDER BRITO'), (2, 'SD'), (3, '139\n')]
# [(0, '77177'), (1, 'TIAGO MOURA'), (2, 'SD'), (3, '235\n')]
# [(0, '77190'), (1, 'SUBTENENTE ELIABE'), (2, 'SD'), (3, '1516\n')]
# [(0, '77192'), (1, 'GILZA BRASIL'), (2, 'SD'), (3, '44\n')]
# [(0, '77211'), (1, 'BAMBAM'), (2, 'SD'), (3, '717\n')]
# [(0, '77217'), (1, 'HENRIQUE CÂMARA'), (2, 'SD'), (3, '301\n')]
# [(0, '77222'), (1, 'PAULINHO FREIRE'), (2, 'SD'), (3, '2884\n')]
# [(0, '77223'), (1, 'SARGENTO ANDREA'), (2, 'SD'), (3, '90\n')]
# [(0, '77224'), (1, 'ANDRESA PRAXEDES'), (2, 'SD'), (3, '7\n')]
# [(0, '77225'), (1, 'IRMÃ VERA'), (2, 'SD'), (3, '524\n')]
# [(0, '77228'), (1, 'RITA DE CASSIA'), (2, 'SD'), (3, '1\n')]
# [(0, '77250'), (1, 'BAYDR'), (2, 'SD'), (3, '311\n')]
# [(0, '77258'), (1, 'SIRLIA'), (2, 'SD'), (3, '161\n')]
# [(0, '77321'), (1, 'TICÃO PARAGUAI'), (2, 'SD'), (3, '209\n')]
# [(0, '77333'), (1, 'ALEXANDRE MELO'), (2, 'SD'), (3, '486\n')]
# [(0, '77444'), (1, 'ROBSON MACEDO'), (2, 'SD'), (3, '108\n')]
# [(0, '77456'), (1, 'RAIMUNDO JORGE'), (2, 'SD'), (3, '1527\n')]
# [(0, '77555'), (1, 'KLAUS ARAUJO'), (2, 'SD'), (3, '2279\n')]
# [(0, '77567'), (1, 'KLEBER AQUINO'), (2, 'SD'), (3, '208\n')]
# [(0, '77611'), (1, 'JAKSON CAPIXABA'), (2, 'SD'), (3, '900\n')]
# [(0, '77654'), (1, 'RAQUEL'), (2, 'SD'), (3, '27\n')]
# [(0, '77666'), (1, 'EUDIANE MACEDO'), (2, 'SD'), (3, '4922\n')]
# [(0, '77678'), (1, 'ZEZINHO DO BOM PASTOR'), (2, 'SD'), (3, '68\n')]
# [(0, '77700'), (1, 'GUSTAVO BRENDO'), (2, 'SD'), (3, '384\n')]
# [(0, '77777'), (1, 'FLAVIO PEIXOTO'), (2, 'SD'), (3, '1374\n')]
# [(0, '77788'), (1, 'CALIXTO DANTAS'), (2, 'SD'), (3, '69\n')]
# [(0, '77789'), (1, 'FREIRE'), (2, 'SD'), (3, '1008\n')]
# [(0, '77888'), (1, 'FULVIO'), (2, 'SD'), (3, '1711\n')]
# [(0, '77890'), (1, 'ANDERSON LOPES'), (2, 'SD'), (3, '1132\n')]
# [(0, '77930'), (1, 'WANESSA BARBOSA'), (2, 'SD'), (3, '1\n')]
# [(0, '77931'), (1, 'JENNYFER LARISY'), (2, 'SD'), (3, '3\n')]
# [(0, '77932'), (1, 'ADRIANA'), (2, 'SD'), (3, '8\n')]
# [(0, '77999'), (1, 'DANIEL MARIZ'), (2, 'SD'), (3, '258\n')]
# [(0, '90111'), (1, 'CARLA DICKSON OFTALMOLOGISTA'), (2, 'PROS - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '7924\n')]
# [(0, '90222'), (1, 'DR FABRICIO SERQUIZ'), (2, 'PROS - PDT / PMDB / PR / PROS / DEM / PSC'), (3, '187\n')]

# %%
with open("eleicao.csv", encoding="utf-8") as f:
    f.readline()
    for line in f: 
        elections = line.split(";")
        parties_coal = elections[2]
        
        if parties_coal in elec_votes:
            elec_votes[parties_coal] += int(elections[3]) # explicit cast
        else:
            elec_votes[parties_coal] = int(elections[3])

print(elec_votes)
# Out:
# {'PRB - PRB / PSDC': 9363, 'PP - PEN / PP': 819, 'PDT - PDT / PMDB / PR / PROS / DEM / PSC': 37213, 'PT': 23200, 'PTB - PSD / PTB / PSL': 7486, 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC': 13768, 'PSTU': 10074, 'PSL - PSD / PTB / PSL': 7334, 'REDE': 497, 'PTN': 15658, 'PSC - PDT / PMDB / PR / PROS / DEM / PSC': 1975, 'PR - PDT / PMDB / PR / PROS / DEM / PSC': 10472, 'PPS - PSB / PPS': 7103, 'DEM - PDT / PMDB / PR / PROS / DEM / PSC': 3487, 'PSDC - PRB / PSDC': 11920, 'PRTB - PRP / PTC / PRTB / PMN': 1157, 'PHS': 15038, 'PMN - PRP / PTC / PRTB / PMN': 2989, 'PMB': 28629, 'PTC - PRP / PTC / PRTB / PMN': 1356, 'PSB - PSB / PPS': 8049, 'PV': 7082, 'PRP - PRP / PTC / PRTB / PMN': 4094, 'PSDB - PSDB / PT do B': 12551, 'PSOL': 17033, 'PEN - PEN / PP': 17795, 'PSD - PSD / PTB / PSL': 15721, 'PC do B': 8429, 'PT do B - PSDB / PT do B': 8449, 'SD': 28224, 'PROS - PDT / PMDB / PR / PROS / DEM / PSC': 8111}

# %%
for i in elec_votes.keys():
    #QP = mt.floor(elec_votes[i]/QE)
    print(elec_votes[i],"-", QE)

    QP = int(elec_votes[i]/QE)
    print(QP)
    if QP > 0:
        chairs_dist[i] = QP

#rs_dist)
# Out:
# 9363 - 12684
# 0
# 819 - 12684
# 0
# 37213 - 12684
# 2
# 23200 - 12684
# 1
# 7486 - 12684
# 0
# 13768 - 12684
# 1
# 10074 - 12684
# 0
# 7334 - 12684
# 0
# 497 - 12684
# 0
# 15658 - 12684
# 1
# 1975 - 12684
# 0
# 10472 - 12684
# 0
# 7103 - 12684
# 0
# 3487 - 12684
# 0
# 11920 - 12684
# 0
# 1157 - 12684
# 0
# 15038 - 12684
# 1
# 2989 - 12684
# 0
# 28629 - 12684
# 2
# 1356 - 12684
# 0
# 8049 - 12684
# 0
# 7082 - 12684
# 0
# 4094 - 12684
# 0
# 12551 - 12684
# 0
# 17033 - 12684
# 1
# 17795 - 12684
# 1
# 15721 - 12684
# 1
# 8429 - 12684
# 0
# 8449 - 12684
# 0
# 28224 - 12684
# 2
# 8111 - 12684
# 0

# %%
QP = {parties: int(votes / QE) for parties, votes in elec_votes.items()}
QP
# Out:
# {'DEM - PDT / PMDB / PR / PROS / DEM / PSC': 0,
#  'PC do B': 0,
#  'PDT - PDT / PMDB / PR / PROS / DEM / PSC': 2,
#  'PEN - PEN / PP': 1,
#  'PHS': 1,
#  'PMB': 2,
#  'PMDB - PDT / PMDB / PR / PROS / DEM / PSC': 1,
#  'PMN - PRP / PTC / PRTB / PMN': 0,
#  'PP - PEN / PP': 0,
#  'PPS - PSB / PPS': 0,
#  'PR - PDT / PMDB / PR / PROS / DEM / PSC': 0,
#  'PRB - PRB / PSDC': 0,
#  'PROS - PDT / PMDB / PR / PROS / DEM / PSC': 0,
#  'PRP - PRP / PTC / PRTB / PMN': 0,
#  'PRTB - PRP / PTC / PRTB / PMN': 0,
#  'PSB - PSB / PPS': 0,
#  'PSC - PDT / PMDB / PR / PROS / DEM / PSC': 0,
#  'PSD - PSD / PTB / PSL': 1,
#  'PSDB - PSDB / PT do B': 0,
#  'PSDC - PRB / PSDC': 0,
#  'PSL - PSD / PTB / PSL': 0,
#  'PSOL': 1,
#  'PSTU': 0,
#  'PT': 1,
#  'PT do B - PSDB / PT do B': 0,
#  'PTB - PSD / PTB / PSL': 0,
#  'PTC - PRP / PTC / PRTB / PMN': 0,
#  'PTN': 1,
#  'PV': 0,
#  'REDE': 0,
#  'SD': 2}

# %%
chairs_left = int(total_cadeiras - sum(filter(lambda elem:elem,(map(lambda M1:float(M1),M1.values())))))
chairs_left
# Out:
# 16

# %%
max(M1.items())
# Out:
# ('SD', 2)

# %%
while chairs_left > 0:
    for key in M1.items():
        if M1[key] > M1[key+1]:
            max
    
    
print(type(M1))
# Out:
# <class 'dict'>

# %%
while chairs_left >0:
    media = {paties: int(votos / QP+i+1) for parties, votos in M1.items()}
    i += 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-235-ace91fdb27c0> in <module>()
#       1 while chairs_left >0:
# ----> 2     media = {paties: int(votos/QP+i+1) for parties, votos in M1.items()}
#       3     i += 1
#
# <ipython-input-235-ace91fdb27c0> in <dictcomp>(.0)
#       1 while chairs_left >0:
# ----> 2     media = {paties: int(votos/QP+i+1) for parties, votos in M1.items()}
#       3     i += 1
#
# TypeError: unsupported operand type(s) for /: 'int' and 'dict'

# %%
media = dict()
while chairs_left > 0:
    for key in QP.items():
        print(chairs_dist[key]+1)
        current_media = elec_votes[key]/(chairs_dist[key]+1)
        print(current_media)
        media[key] = current_media
        
    media_winner = max(media, key=media.get)
    chairs_dist[media_winner] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-230-2b8837084890> in <module>()
#       2 while chairs_left > 0:
#       3     for key in QP.items():
# ----> 4         print(chairs_dist[key]+1)
#       5         current_media = elec_votes[key]/(chairs_dist[key]+1)
#       6         print(current_media)
#
# KeyError: ('PRB - PRB / PSDC', 0)

# %%
import pandas as pd

data = pd.read_csv("eleicao.csv", sep=";")
data
# Out:
#      Número                          Nome  \
# 0     10000                ANTONIO JUNIOR
# 1     10010                       CIDINHA
# 2     10100             GABRIEL NEGREIROS
# 3     10111                 JÚNIOR FRANÇA
# 4     10123        PROFª MADALENA PEIXOTO
# 5     10131                 LUCIA ARDUINI
# 6     10144                  HERÓ BEZERRA
# 7     10177                MYRNA KARENINA
# 8     10200                       RIBAMAR
# 9     10222                          DAVI
# 10    10333      BISPO FRANCISCO DE ASSIS
# 11    10444          PASTOR TARQUINO JOSÉ
# 12    10555                    KELLY MAIA
# 13    10777          IRMÃO JOÃO DA BENÇÃO
# 14    10789                 JOÃO DA COSTA
# 15    10888                    CRIS ROCHA
# 16    10999                        VENINA
# 17    11111                        VICTOR
# 18    11112                JADELSON SALES
# 19    11123                WESLEY BISMARK
# 20    12000                JUNIOR GRAFITH
# 21    12002           PAULINHA COSTUREIRA
# 22    12007             DUCIRENE OLIVEIRA
# 23    12012                   EIDER ALVES
# 24    12100                 RODRIGO GOMES
# 25    12110              FERNANDO SARAIVA
# 26    12111               RANIERE BARBOSA
# 27    12114                 NECY TEIXEIRA
# 28    12122            VALERIA CAVALCANTI
# 29    12123                         SÁVIO
# ..      ...                           ...
# 533   77217               HENRIQUE CÂMARA
# 534   77222               PAULINHO FREIRE
# 535   77223               SARGENTO ANDREA
# 536   77224              ANDRESA PRAXEDES
# 537   77225                     IRMÃ VERA
# 538   77228                RITA DE CASSIA
# 539   77250                         BAYDR
# 540   77258                        SIRLIA
# 541   77321                TICÃO PARAGUAI
# 542   77333                ALEXANDRE MELO
# 543   77444                 ROBSON MACEDO
# 544   77456                RAIMUNDO JORGE
# 545   77555                  KLAUS ARAUJO
# 546   77567                 KLEBER AQUINO
# 547   77611               JAKSON CAPIXABA
# 548   77654                        RAQUEL
# 549   77666                EUDIANE MACEDO
# 550   77678         ZEZINHO DO BOM PASTOR
# 551   77700                GUSTAVO BRENDO
# 552   77777                FLAVIO PEIXOTO
# 553   77788                CALIXTO DANTAS
# 554   77789                        FREIRE
# 555   77888                        FULVIO
# 556   77890                ANDERSON LOPES
# 557   77930               WANESSA BARBOSA
# 558   77931               JENNYFER LARISY
# 559   77932                       ADRIANA
# 560   77999                  DANIEL MARIZ
# 561   90111  CARLA DICKSON OFTALMOLOGISTA
# 562   90222           DR FABRICIO SERQUIZ
#
#                              Partido/Coligação  Votos
# 0                             PRB - PRB / PSDC    434
# 1                             PRB - PRB / PSDC     36
# 2                             PRB - PRB / PSDC    280
# 3                             PRB - PRB / PSDC    568
# 4                             PRB - PRB / PSDC    382
# 5                             PRB - PRB / PSDC     20
# 6                             PRB - PRB / PSDC    422
# 7                             PRB - PRB / PSDC    209
# 8                             PRB - PRB / PSDC     91
# 9                             PRB - PRB / PSDC    409
# 10                            PRB - PRB / PSDC   5160
# 11                            PRB - PRB / PSDC    340
# 12                            PRB - PRB / PSDC    175
# 13                            PRB - PRB / PSDC    509
# 14                            PRB - PRB / PSDC    217
# 15                            PRB - PRB / PSDC     63
# 16                            PRB - PRB / PSDC     48
# 17                               PP - PEN / PP    480
# 18                               PP - PEN / PP    169
# 19                               PP - PEN / PP    170
# 20    PDT - PDT / PMDB / PR / PROS / DEM / PSC   1635
# 21    PDT - PDT / PMDB / PR / PROS / DEM / PSC    159
# 22    PDT - PDT / PMDB / PR / PROS / DEM / PSC     72
# 23    PDT - PDT / PMDB / PR / PROS / DEM / PSC    189
# 24    PDT - PDT / PMDB / PR / PROS / DEM / PSC     78
# 25    PDT - PDT / PMDB / PR / PROS / DEM / PSC    312
# 26    PDT - PDT / PMDB / PR / PROS / DEM / PSC  10510
# 27    PDT - PDT / PMDB / PR / PROS / DEM / PSC      0
# 28    PDT - PDT / PMDB / PR / PROS / DEM / PSC    714
# 29    PDT - PDT / PMDB / PR / PROS / DEM / PSC   1435
# ..                                         ...    ...
# 533                                         SD    301
# 534                                         SD   2884
# 535                                         SD     90
# 536                                         SD      7
# 537                                         SD    524
# 538                                         SD      1
# 539                                         SD    311
# 540                                         SD    161
# 541                                         SD    209
# 542                                         SD    486
# 543                                         SD    108
# 544                                         SD   1527
# 545                                         SD   2279
# 546                                         SD    208
# 547                                         SD    900
# 548                                         SD     27
# 549                                         SD   4922
# 550                                         SD     68
# 551                                         SD    384
# 552                                         SD   1374
# 553                                         SD     69
# 554                                         SD   1008
# 555                                         SD   1711
# 556                                         SD   1132
# 557                                         SD      1
# 558                                         SD      3
# 559                                         SD      8
# 560                                         SD    258
# 561  PROS - PDT / PMDB / PR / PROS / DEM / PSC   7924
# 562  PROS - PDT / PMDB / PR / PROS / DEM / PSC    187
#
# [563 rows x 4 columns]

# %%
coligacao_votos = dict()

partidos = data["Partido/Coligação"]
    if partidos in coligacao_votos

# %%
colig = data["Partido/Coligação"].unique()
colig
# Out:
# array(['PRB - PRB / PSDC', 'PP - PEN / PP',
#        'PDT - PDT / PMDB / PR / PROS / DEM / PSC', 'PT',
#        'PTB - PSD / PTB / PSL',
#        'PMDB - PDT / PMDB / PR / PROS / DEM / PSC', 'PSTU',
#        'PSL - PSD / PTB / PSL', 'REDE', 'PTN',
#        'PSC - PDT / PMDB / PR / PROS / DEM / PSC',
#        'PR - PDT / PMDB / PR / PROS / DEM / PSC', 'PPS - PSB / PPS',
#        'DEM - PDT / PMDB / PR / PROS / DEM / PSC', 'PSDC - PRB / PSDC',
#        'PRTB - PRP / PTC / PRTB / PMN', 'PHS',
#        'PMN - PRP / PTC / PRTB / PMN', 'PMB',
#        'PTC - PRP / PTC / PRTB / PMN', 'PSB - PSB / PPS', 'PV',
#        'PRP - PRP / PTC / PRTB / PMN', 'PSDB - PSDB / PT do B', 'PSOL',
#        'PEN - PEN / PP', 'PSD - PSD / PTB / PSL', 'PC do B',
#        'PT do B - PSDB / PT do B', 'SD',
#        'PROS - PDT / PMDB / PR / PROS / DEM / PSC'], dtype=object)

# %%
partidos = []
coligacoes = []
for i in colig:
    if len(i) > 4:
        coligacoes.append(i)
    else:
        partidos.append(i)
print(partidos)
print(coligacoes)
# Out:
# ['PT', 'PSTU', 'REDE', 'PTN', 'PHS', 'PMB', 'PV', 'PSOL', 'SD']
# ['PRB - PRB / PSDC', 'PP - PEN / PP', 'PDT - PDT / PMDB / PR / PROS / DEM / PSC', 'PTB - PSD / PTB / PSL', 'PMDB - PDT / PMDB / PR / PROS / DEM / PSC', 'PSL - PSD / PTB / PSL', 'PSC - PDT / PMDB / PR / PROS / DEM / PSC', 'PR - PDT / PMDB / PR / PROS / DEM / PSC', 'PPS - PSB / PPS', 'DEM - PDT / PMDB / PR / PROS / DEM / PSC', 'PSDC - PRB / PSDC', 'PRTB - PRP / PTC / PRTB / PMN', 'PMN - PRP / PTC / PRTB / PMN', 'PTC - PRP / PTC / PRTB / PMN', 'PSB - PSB / PPS', 'PRP - PRP / PTC / PRTB / PMN', 'PSDB - PSDB / PT do B', 'PEN - PEN / PP', 'PSD - PSD / PTB / PSL', 'PC do B', 'PT do B - PSDB / PT do B', 'PROS - PDT / PMDB / PR / PROS / DEM / PSC']

# %%
print(data['Partido/Coligação'].unique())
sum(data['Votos'])
# Out:
# ['PRB - PRB / PSDC' 'PP - PEN / PP'
#  'PDT - PDT / PMDB / PR / PROS / DEM / PSC' 'PT' 'PTB - PSD / PTB / PSL'
#  'PMDB - PDT / PMDB / PR / PROS / DEM / PSC' 'PSTU'
#  'PSL - PSD / PTB / PSL' 'REDE' 'PTN'
#  'PSC - PDT / PMDB / PR / PROS / DEM / PSC'
#  'PR - PDT / PMDB / PR / PROS / DEM / PSC' 'PPS - PSB / PPS'
#  'DEM - PDT / PMDB / PR / PROS / DEM / PSC' 'PSDC - PRB / PSDC'
#  'PRTB - PRP / PTC / PRTB / PMN' 'PHS' 'PMN - PRP / PTC / PRTB / PMN'
#  'PMB' 'PTC - PRP / PTC / PRTB / PMN' 'PSB - PSB / PPS' 'PV'
#  'PRP - PRP / PTC / PRTB / PMN' 'PSDB - PSDB / PT do B' 'PSOL'
#  'PEN - PEN / PP' 'PSD - PSD / PTB / PSL' 'PC do B'
#  'PT do B - PSDB / PT do B' 'SD'
#  'PROS - PDT / PMDB / PR / PROS / DEM / PSC']
# 345076

# %%
#data.loc['Partido/Coligação']

# %%
#votos_colig = []
#for i in data.iloc['Partido/Coligação']:
#    for j in data.loc['Votos']:
#        votos_colig.append(i,j)

# %%
#partidos_votos = partidos[partidos.Votos]
